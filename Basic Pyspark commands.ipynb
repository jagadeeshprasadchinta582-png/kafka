# %%
# %sql
Use Catalog jagadeesh;
USE SCHEMA healthcare;
create table myhealthcare

# %%
# %fs ls /Volumes/jagadeesh/healthcare/myvolume/health_opas.csv

# %%
df.write.format('delta').mode('overwrite').option('delta.columnMapping.mode', 'name').saveAsTable('jagadeesh.healthcare.mydata1')

# %%
df3= spark.read.format("delta").load('dbfs:/jagadeesh.healthcare.mydata1')
display(df3)

# %%
df= spark.read.format("csv").option("header", "true").load('dbfs:/Volumes/jagadeesh/healthcare/myvolume/health_opas.csv')
display(df)

# %%
spark.sql("CREATE CATALOG IF NOT EXISTS my_PYSPARK")
spark.sql("CREATE SCHEMA IF NOT EXISTS my_PYSPARK.my_TEST")
spark.sql("create table if not exists my_PYSPARK.my_TEST.my_table (id int, name string)")
spark.sql("insert into my_PYSPARK.my_TEST.my_table values (1, 'John'), (2, 'Jane') , (3, 'Mary '), (4, 'Bob ')")

# %%
df = spark.table("my_PYSPARK.my_TEST.my_table")
display(df)
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
df1= spark.table("my_PYSPARK.my_TEST.customers")
display(df1)

# %%
display(df1.select("COUNTRY", "TERRITORY", "EMAIL").distinct())

# %%
display (df1.where(df1.TERRITORY == "NA"))

# %%
newtable = df1.where(df1.TERRITORY == "NA")
newtable.write.saveAsTable("my_PYSPARK.my_TEST.customers_na")
display(spark.table("my_PYSPARK.my_TEST.customers_na"))
